# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'data/2010-2018_county_state_year_pop-unemployment-income-poverty.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#   location  year  population  unemployment_rate  mean_household_income
# 0  Alabama  2010       54571                  6                  64733
# 1  Alabama  2010      182265                  7                  66054
# 2  Alabama  2010       27457                 10                  41710
# 3  Alabama  2010       22915                  9                  52292
# 4  Alabama  2010       57322                  8                  55476

# %%
file_path = 'data/Capstone Info1.xlsx'
xl = pd.ExcelFile(file_path)

sheet_name = 'all drug OD Deaths'
od_deaths_df = pd.read_excel(file_path, sheet_name=sheet_name)

# %%
od_deaths_cleaned_df = od_deaths_df.fillna(0)

# %%
od_deaths_long_df = pd.melt(od_deaths_cleaned_df, id_vars=['Unnamed: 0'], var_name='Year', value_name='Deaths')

# %%
od_deaths_long_df.rename(columns={'Unnamed: 0': 'Category'}, inplace=True)

# %%
output_file_path = 'clean_od.csv'
od_deaths_long_df.to_csv(output_file_path, index=False)

# %%
file_path = 'data/Capstone Info1.xlsx'
xl = pd.ExcelFile(file_path)

od_deaths_df = pd.read_excel(file_path, sheet_name='all drug OD Deaths')

# Clean the data: Replace any NaN values with 0 (assuming NaN means no deaths recorded)
od_deaths_cleaned_df = od_deaths_df.fillna(0)
od_deaths_long_df = pd.melt(od_deaths_cleaned_df, id_vars=['Unnamed: 0'], var_name='Year', value_name='Deaths')

od_deaths_long_df.rename(columns={'Unnamed: 0': 'Category'}, inplace=True)

od_deaths_long_df.head()
# Out:
#                   Category  Year  Deaths
# 0    Total Overdose Deaths  1999   16849
# 1                   Female  1999    5591
# 2                     Male  1999   11258
# 3               Any Opioid  1999    8050
# 4                   Female  1999    2057

# %%
# Save the cleaned and reshaped data to a new CSV file
output_file_path = 'data/Cleaned_OD_Deaths_Data.csv'
od_deaths_long_df.to_csv(output_file_path, index=False)

output_file_path
# Out:
# 'data/Cleaned_OD_Deaths_Data.csv'

# %%
file_path = 'data/ages_15_24 1991-2021.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#                 Category    1999    2000    2001    2002    2003    2004  \
# 0  Total Overdose Deaths  1240.0  1435.0  1700.0  2095.0  2491.0  2751.0
# 1                 Female   346.0   369.0   438.0   560.0   632.0   683.0
# 2                   Male   894.0  1066.0  1262.0  1535.0  1859.0  2068.0
# 3             Any Opioid   621.0   728.0   944.0  1179.0  1399.0  1596.0
# 4                 Female   141.0   140.0   203.0   269.0   306.0   333.0
#
#      2005    2006    2007  ...    2012    2013  2014    2015  2016  2017  \
# 0  2918.0  3460.0  3550.0  ...  3518.0  3664.0  3798  4235.0  5376  5455
# 1   733.0   820.0   883.0  ...   945.0  1028.0  1075  1258.0  1483  1663
# 2  2185.0  2640.0  2667.0  ...  2573.0  2636.0  2723  2977.0  3893  3792
# 3  1685.0  2096.0  2176.0  ...  2344.0  2486.0  2706  3082.0  4027  4094
# 4   371.0   444.0   491.0  ...   574.0   640.0   711   871.0  1041  1209
#
#    2018  2019  2020  2021
# 0  4633  4777  7095  7426
# 1  1481  1459  1990  2311
# 2  3152  3318  5105  5115
# 3  3618  3725  5986  6312
# 4  1091  1058  1584  1866
#
# [5 rows x 24 columns]

# %%
file_path_newest = 'data/data-table.csv'
heatmap_usa_data = pd.read_csv(file_path_newest)

heatmap_usa_data.head()
# Out:
#    YEAR STATE  RATE DEATHS                                       URL
# 0  2021    AL  30.1   1408     /nchs/pressroom/states/alabama/al.htm
# 1  2021    AK  35.6    260      /nchs/pressroom/states/alaska/ak.htm
# 2  2021    AZ  38.7   2730     /nchs/pressroom/states/arizona/az.htm
# 3  2021    AR  22.3    637    /nchs/pressroom/states/arkansas/ar.htm
# 4  2021    CA  26.6  10901  /nchs/pressroom/states/california/ca.htm

# %%
# Load the new dataset
file_path_latest = 'data/data-table.csv'
latest_data = pd.read_csv(file_path_latest)

# Display the first few rows of the new dataset
latest_data.head()
# Out:
#    YEAR STATE  RATE DEATHS                                       URL
# 0  2021    AL  30.1   1408     /nchs/pressroom/states/alabama/al.htm
# 1  2021    AK  35.6    260      /nchs/pressroom/states/alaska/ak.htm
# 2  2021    AZ  38.7   2730     /nchs/pressroom/states/arizona/az.htm
# 3  2021    AR  22.3    637    /nchs/pressroom/states/arkansas/ar.htm
# 4  2021    CA  26.6  10901  /nchs/pressroom/states/california/ca.htm

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Load opioid deaths data
deaths_data = pd.read_csv('path_to_data-table.csv')

# Filter for 2021 data
deaths_2021 = deaths_data[deaths_data['YEAR'] == 2021]

# Load state boundaries
states = gpd.read_file('path_to_state_boundaries_shapefile.shp')

# Merge data
map_data = states.merge(deaths_2021, left_on='state_code', right_on='STATE')

# Plot
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
map_data.plot(column='RATE', ax=ax, legend=True, cmap='OrRd')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[43], line 6
#       3 import matplotlib.pyplot as plt
#       5 # Load opioid deaths data
# ----> 6 deaths_data = pd.read_csv('path_to_data-table.csv')
#       8 # Filter for 2021 data
#       9 deaths_2021 = deaths_data[deaths_data['YEAR'] == 2021]
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_data-table.csv'

# %%
# Load the provided CSV files
file_path_1 = 'data/data-table.csv'
file_path_2 = 'data/mappy.csv'

df1 = pd.read_csv(file_path_1)
df2 = pd.read_csv(file_path_2)

df1_head = df1.head()
df2_head = df2.head()

df1_head, df2_head
# Out:
# (   YEAR STATE  RATE DEATHS                                       URL
#  0  2021    AL  30.1   1408     /nchs/pressroom/states/alabama/al.htm
#  1  2021    AK  35.6    260      /nchs/pressroom/states/alaska/ak.htm
#  2  2021    AZ  38.7   2730     /nchs/pressroom/states/arizona/az.htm
#  3  2021    AR  22.3    637    /nchs/pressroom/states/arkansas/ar.htm
#  4  2021    CA  26.6  10901  /nchs/pressroom/states/california/ca.htm,
#    original_original_location  original_original_year  \
#  0                    Alabama                    2010
#  1                    Alabama                    2010
#  2                    Alabama                    2010
#  3                    Alabama                    2010
#  4                    Alabama                    2010
#
#     original_original_population  original_original_unemployment_rate  \
#  0                         54571                                    6
#  1                        182265                                    7
#  2                         27457                                   10
#  3                         22915                                    9
#  4                         57322                                    8
#
#     original_original_mean_household_income  original_lat  original_lon  \
#  0                                    64733     33.258882    -86.829534
#  1                                    66054     33.258882    -86.829534
#  2                                    41710     33.258882    -86.829534
#  3                                    52292     33.258882    -86.829534
#  4                                    55476     33.258882    -86.829534
#
#                    original_formatted original_state original_state_code  ...  \
#  0  Alabama, United States of America        Alabama                  AL  ...
#  1  Alabama, United States of America        Alabama                  AL  ...
#  2  Alabama, United States of America        Alabama                  AL  ...
#  3  Alabama, United States of America        Alabama                  AL  ...
#  4  Alabama, United States of America        Alabama                  AL  ...
#
#    postcode       city         county    state state_code        country  \
#  0  35007.0  Alabaster  Shelby County  Alabama         AL  United States
#  1  35007.0  Alabaster  Shelby County  Alabama         AL  United States
#  2  35007.0  Alabaster  Shelby County  Alabama         AL  United States
#  3  35007.0  Alabaster  Shelby County  Alabama         AL  United States
#  4  35007.0  Alabaster  Shelby County  Alabama         AL  United States
#
#     country_code                   attribution   attribution_license  \
#  0            us  © OpenAddresses contributors  BSD-3-Clause License
#  1            us  © OpenAddresses contributors  BSD-3-Clause License
#  2            us  © OpenAddresses contributors  BSD-3-Clause License
#  3            us  © OpenAddresses contributors  BSD-3-Clause License
#  4            us  © OpenAddresses contributors  BSD-3-Clause License
#
#     attribution_url
#  0              NaN
#  1              NaN
#  2              NaN
#  3              NaN
#  4              NaN
#
#  [5 rows x 34 columns])

# %%
file_path_map = 'data/mappy.csv'

df_map = pd.read_csv(file_path_map)

latitudes = df_map['original_lat']
longitudes = df_map['original_lon']
data_heatmap = list(zip(latitudes, longitudes))

map_heat = folium.Map(location=[37.0902, -95.7129], zoom_start=5)  # Centered on the USA

HeatMap(data_heatmap).add_to(map_heat)

output_file_path_final_corrected = 'data/heatmap_final_corrected.html'
map_heat.save(output_file_path_final_corrected)

output_file_path_final_corrected
# Out:
# 'data/heatmap_final_corrected.html'

# %%
file_path_deaths = 'data/data-table.csv'
file_path_map = 'data/mappy.csv'

df_deaths = pd.read_csv(file_path_deaths)
df_map = pd.read_csv(file_path_map)

df_deaths['STATE'] = df_deaths['STATE'].str.upper()

df_merged = pd.merge(df_deaths, df_map, left_on='STATE', right_on='original_state_code')


state_coordinates = df_merged.groupby('STATE')[['original_lat', 'original_lon']].mean().reset_index()

df_heatmap_data = pd.merge(df_deaths, state_coordinates, on='STATE')

heatmap_data = df_heatmap_data[['original_lat', 'original_lon', 'RATE']].dropna()
heatmap_data['RATE'] = heatmap_data['RATE'].astype(float)

map_heat = folium.Map(location=[37.0902, -95.7129], zoom_start=5)  # Centered on the USA

heat_data = [[row['original_lat'], row['original_lon'], row['RATE']] for index, row in heatmap_data.iterrows()]
HeatMap(heat_data, radius=15).add_to(map_heat)

output_file_path_opioid_heatmap_redone = 'data/opioid_heatmap_redone.html'
map_heat.save(output_file_path_opioid_heatmap_redone)

output_file_path_opioid_heatmap_redone
# Out:
# 'data/opioid_heatmap_redone.html'

# %%
file_path_2019_2022 = 'data/nationwide-drugs-fy19-fy22.csv'
file_path_2020_2023 = 'data/nationwide-drugs-fy20-fy23.csv'

data_2019_2022 = pd.read_csv(file_path_2019_2022)
data_2020_2023 = pd.read_csv(file_path_2020_2023)

data_2019_2022.head(), data_2020_2023.head()
# Out:
# (     FY Month (abbv)                   Component            Region  \
#  0  2019          APR  Office of Field Operations  Coastal/Interior
#  1  2019          APR  Office of Field Operations  Coastal/Interior
#  2  2019          APR  Office of Field Operations  Coastal/Interior
#  3  2019          APR  Office of Field Operations  Coastal/Interior
#  4  2019          APR  Office of Field Operations  Coastal/Interior
#
#    Land Filter  Area of Responsibility            Drug Type  Count of Event  \
#  0       Other    ATLANTA FIELD OFFICE              Ecstasy               3
#  1       Other    ATLANTA FIELD OFFICE  Khat (Catha Edulis)               4
#  2       Other    ATLANTA FIELD OFFICE            Marijuana               5
#  3       Other    ATLANTA FIELD OFFICE        Other Drugs**               8
#  4       Other  BALTIMORE FIELD OFFICE              Cocaine               3
#
#     Sum Qty (lbs)
#  0       8.379947
#  1    1394.423807
#  2       0.089397
#  3      42.663196
#  4       8.542913  ,
#       FY Month (abbv)                   Component            Region  \
#  0  2020          APR  Office of Field Operations  Coastal/Interior
#  1  2020          APR  Office of Field Operations  Coastal/Interior
#  2  2020          APR  Office of Field Operations  Coastal/Interior
#  3  2020          APR  Office of Field Operations  Coastal/Interior
#  4  2020          APR  Office of Field Operations  Coastal/Interior
#
#    Land Filter  Area of Responsibility            Drug Type  Count of Event  \
#  0       Other    ATLANTA FIELD OFFICE        Other Drugs**               2
#  1       Other  BALTIMORE FIELD OFFICE             Ketamine               1
#  2       Other  BALTIMORE FIELD OFFICE  Khat (Catha Edulis)               2
#  3       Other  BALTIMORE FIELD OFFICE        Other Drugs**              13
#  4       Other    CHICAGO FIELD OFFICE              Cocaine               7
#
#     Sum Qty (lbs)
#  0       0.330693
#  1       0.017417
#  2    1137.497087
#  3       5.258907
#  4     125.697881  )

# %%
merged_data = pd.concat([data_2019_2022, data_2020_2023])

total_quantity_by_drug = merged_data.groupby('Drug Type')['Sum Qty (lbs)'].sum().sort_values(ascending=False)

events_by_drug = merged_data.groupby('Drug Type')['Count of Event'].sum().sort_values(ascending=False)

monthly_trends = merged_data.groupby(['FY', 'Month (abbv)'])['Sum Qty (lbs)'].sum().reset_index()

regional_variation = merged_data.groupby(['Region', 'Drug Type'])['Sum Qty (lbs)'].sum().reset_index()

plt.figure(figsize=(15, 6))

# Plot for total quantity by drug
plt.subplot(2, 2, 1)
sns.barplot(x=total_quantity_by_drug.index, y=total_quantity_by_drug.values)
plt.xticks(rotation=45)
plt.title('Total Quantity of Each Drug Type Seized (2019-2023)')
plt.ylabel('Total Quantity (lbs)')
plt.xlabel('Drug Type')

# Plot for number of events per drug type
plt.subplot(2, 2, 2)
sns.barplot(x=events_by_drug.index, y=events_by_drug.values)
plt.xticks(rotation=45)
plt.title('Number of Events Per Drug Type')
plt.ylabel('Count of Events')
plt.xlabel('Drug Type')

# Plot for monthly trends
plt.subplot(2, 2, 3)
sns.lineplot(data=monthly_trends, x='Month (abbv)', y='Sum Qty (lbs)', hue='FY')
plt.title('Monthly Drug Seizure Trends (2019-2023)')
plt.ylabel('Total Quantity (lbs)')
plt.xlabel('Month')

# Plot for regional variations
plt.subplot(2, 2, 4)
sns.barplot(x='Sum Qty (lbs)', y='Drug Type', hue='Region', data=regional_variation)
plt.title('Regional Variations in Drug Seizures')
plt.ylabel('Drug Type')
plt.xlabel('Total Quantity (lbs)')

plt.tight_layout()
plt.show()

# %%
opioids_list = ['Fentanyl', 'Heroin', 'Other Opioids']
opioid_data = merged_data[merged_data['Drug Type'].isin(opioids_list)]

# Total quantity of opioids seized over the years
opioid_quantity_by_year = opioid_data.groupby(['Drug Type', 'FY'])['Sum Qty (lbs)'].sum().reset_index()

# Trends in opioid seizures over the months
opioid_monthly_trends = opioid_data.groupby(['Drug Type', 'FY', 'Month (abbv)'])['Sum Qty (lbs)'].sum().reset_index()

# Regional variations in opioid seizures
opioid_regional_variation = opioid_data.groupby(['Region', 'Drug Type'])['Sum Qty (lbs)'].sum().reset_index()

plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
sns.barplot(x='FY', y='Sum Qty (lbs)', hue='Drug Type', data=opioid_quantity_by_year)
plt.title('Total Quantity of Opioids Seized by Year')
plt.ylabel('Total Quantity (lbs)')
plt.xlabel('Fiscal Year')

plt.subplot(1, 3, 2)
sns.lineplot(data=opioid_monthly_trends, x='Month (abbv)', y='Sum Qty (lbs)', hue='Drug Type')
plt.title('Monthly Opioid Seizure Trends')
plt.ylabel('Total Quantity (lbs)')
plt.xlabel('Month')

plt.subplot(1, 3, 3)
sns.barplot(x='Sum Qty (lbs)', y='Drug Type', hue='Region', data=opioid_regional_variation)
plt.title('Regional Variations in Opioid Seizures')
plt.ylabel('Drug Type')
plt.xlabel('Total Quantity (lbs)')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
sns.barplot(x='FY', y='Sum Qty (lbs)', hue='Drug Type', data=opioid_quantity_by_year, palette=custom_colors)
plt.title('Total Quantity of Opioids Seized by Year')
plt.ylabel('Total Quantity (lbs)')
plt.xlabel('Fiscal Year')

plt.subplot(1, 3, 2)
sns.lineplot(data=opioid_monthly_trends, x='Month (abbv)', y='Sum Qty (lbs)', hue='Drug Type', palette=custom_colors)
plt.title('Monthly Opioid Seizure Trends')
plt.ylabel('Total Quantity (lbs)')
plt.xlabel('Month')

plt.subplot(1, 3, 3)
sns.barplot(x='Sum Qty (lbs)', y='Drug Type', hue='Region', data=opioid_regional_variation)
plt.title('Regional Variations in Opioid Seizures')
plt.ylabel('Drug Type')
plt.xlabel('Total Quantity (lbs)')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 plt.figure(figsize=(18, 6))
#       3 plt.subplot(1, 3, 1)
# ----> 4 sns.barplot(x='FY', y='Sum Qty (lbs)', hue='Drug Type', data=opioid_quantity_by_year, palette=custom_colors)
#       5 plt.title('Total Quantity of Opioids Seized by Year')
#       6 plt.ylabel('Total Quantity (lbs)')
#
# NameError: name 'opioid_quantity_by_year' is not defined

# %%
file_path_1 = 'data/nationwide-drugs-fy19-fy22.csv'
data_1 = pd.read_csv(file_path_1)

data_1.head()
# Out:
#      FY Month (abbv)                   Component            Region  \
# 0  2019          APR  Office of Field Operations  Coastal/Interior
# 1  2019          APR  Office of Field Operations  Coastal/Interior
# 2  2019          APR  Office of Field Operations  Coastal/Interior
# 3  2019          APR  Office of Field Operations  Coastal/Interior
# 4  2019          APR  Office of Field Operations  Coastal/Interior
#
#   Land Filter  Area of Responsibility            Drug Type  Count of Event  \
# 0       Other    ATLANTA FIELD OFFICE              Ecstasy               3
# 1       Other    ATLANTA FIELD OFFICE  Khat (Catha Edulis)               4
# 2       Other    ATLANTA FIELD OFFICE            Marijuana               5
# 3       Other    ATLANTA FIELD OFFICE        Other Drugs**               8
# 4       Other  BALTIMORE FIELD OFFICE              Cocaine               3
#
#    Sum Qty (lbs)
# 0       8.379947
# 1    1394.423807
# 2       0.089397
# 3      42.663196
# 4       8.542913

# %%
file_path_2 = 'data/nationwide-drugs-fy20-fy23.csv'
data_2 = pd.read_csv(file_path_2)

data_2.head()
# Out:
#      FY Month (abbv)                   Component            Region  \
# 0  2020          APR  Office of Field Operations  Coastal/Interior
# 1  2020          APR  Office of Field Operations  Coastal/Interior
# 2  2020          APR  Office of Field Operations  Coastal/Interior
# 3  2020          APR  Office of Field Operations  Coastal/Interior
# 4  2020          APR  Office of Field Operations  Coastal/Interior
#
#   Land Filter  Area of Responsibility            Drug Type  Count of Event  \
# 0       Other    ATLANTA FIELD OFFICE        Other Drugs**               2
# 1       Other  BALTIMORE FIELD OFFICE             Ketamine               1
# 2       Other  BALTIMORE FIELD OFFICE  Khat (Catha Edulis)               2
# 3       Other  BALTIMORE FIELD OFFICE        Other Drugs**              13
# 4       Other    CHICAGO FIELD OFFICE              Cocaine               7
#
#    Sum Qty (lbs)
# 0       0.330693
# 1       0.017417
# 2    1137.497087
# 3       5.258907
# 4     125.697881

# %%
combined_data = pd.concat([data_1, data_2])

unique_drug_types = combined_data['Drug Type'].unique()
unique_drug_types.sort()
unique_drug_types.tolist()
# Out:
# ['Cocaine',
#  'Ecstasy',
#  'Fentanyl',
#  'Heroin',
#  'Ketamine',
#  'Khat (Catha Edulis)',
#  'Lsd',
#  'Marijuana',
#  'Methamphetamine',
#  'Other Drugs**']

# %%
opioid_data = combined_data[combined_data['Drug Type'].isin(['Fentanyl', 'Heroin'])]

unique_regions = opioid_data['Region'].unique()
unique_areas = opioid_data['Area of Responsibility'].unique()

(unique_regions.tolist(), unique_areas.tolist())
# Out:
# (['Coastal/Interior', 'Northern Border', 'Southwest Border'],
#  ['BALTIMORE FIELD OFFICE',
#   'CHICAGO FIELD OFFICE',
#   'LOS ANGELES FIELD OFFICE',
#   'MIAMI FIELD OFFICE',
#   'NEW ORLEANS FIELD OFFICE',
#   'NEW YORK FIELD OFFICE',
#   'SAN FRANCISCO FIELD OFFICE',
#   'BUFFALO FIELD OFFICE',
#   'SEATTLE FIELD OFFICE',
#   'EL PASO FIELD OFFICE',
#   'LAREDO FIELD OFFICE',
#   'SAN DIEGO FIELD OFFICE',
#   'TUCSON FIELD OFFICE',
#   'HAVRE SECTOR',
#   'EL CENTRO SECTOR',
#   'LAREDO SECTOR',
#   'RIO GRANDE VALLEY SECTOR',
#   'SAN DIEGO SECTOR',
#   'TUCSON SECTOR',
#   'YUMA SECTOR',
#   'SAN JUAN FIELD OFFICE',
#   'TAMPA FIELD OFFICE',
#   'DETROIT FIELD OFFICE',
#   'HOULTON SECTOR',
#   'BIG BEND SECTOR',
#   'EL PASO SECTOR',
#   'ATLANTA FIELD OFFICE',
#   'BUFFALO SECTOR',
#   'DETROIT SECTOR',
#   'DEL RIO SECTOR',
#   'RAMEY SECTOR',
#   'MIAMI SECTOR',
#   'SPOKANE SECTOR',
#   'HOUSTON FIELD OFFICE',
#   'GRAND FORKS SECTOR',
#   'BLAINE SECTOR',
#   'NEW ORLEANS SECTOR',
#   'PORTLAND FIELD OFFICE',
#   'BOSTON FIELD OFFICE',
#   'PRECLEARANCE FIELD OFFICE',
#   'SWANTON SECTOR'])

# %%
opioid_data = combined_data[combined_data['Drug Type'].isin(['Fentanyl', 'Heroin'])]

unique_regions = opioid_data['Region'].unique()
unique_areas = opioid_data['Area of Responsibility'].unique()

(unique_regions.tolist(), unique_areas.tolist())
# Out:
# (['Coastal/Interior', 'Northern Border', 'Southwest Border'],
#  ['BALTIMORE FIELD OFFICE',
#   'CHICAGO FIELD OFFICE',
#   'LOS ANGELES FIELD OFFICE',
#   'MIAMI FIELD OFFICE',
#   'NEW ORLEANS FIELD OFFICE',
#   'NEW YORK FIELD OFFICE',
#   'SAN FRANCISCO FIELD OFFICE',
#   'BUFFALO FIELD OFFICE',
#   'SEATTLE FIELD OFFICE',
#   'EL PASO FIELD OFFICE',
#   'LAREDO FIELD OFFICE',
#   'SAN DIEGO FIELD OFFICE',
#   'TUCSON FIELD OFFICE',
#   'HAVRE SECTOR',
#   'EL CENTRO SECTOR',
#   'LAREDO SECTOR',
#   'RIO GRANDE VALLEY SECTOR',
#   'SAN DIEGO SECTOR',
#   'TUCSON SECTOR',
#   'YUMA SECTOR',
#   'SAN JUAN FIELD OFFICE',
#   'TAMPA FIELD OFFICE',
#   'DETROIT FIELD OFFICE',
#   'HOULTON SECTOR',
#   'BIG BEND SECTOR',
#   'EL PASO SECTOR',
#   'ATLANTA FIELD OFFICE',
#   'BUFFALO SECTOR',
#   'DETROIT SECTOR',
#   'DEL RIO SECTOR',
#   'RAMEY SECTOR',
#   'MIAMI SECTOR',
#   'SPOKANE SECTOR',
#   'HOUSTON FIELD OFFICE',
#   'GRAND FORKS SECTOR',
#   'BLAINE SECTOR',
#   'NEW ORLEANS SECTOR',
#   'PORTLAND FIELD OFFICE',
#   'BOSTON FIELD OFFICE',
#   'PRECLEARANCE FIELD OFFICE',
#   'SWANTON SECTOR'])

# %%
southwest_border_data = combined_data[(combined_data['Region'] == 'Southwest Border') & 
                                      combined_data['Drug Type'].isin(['Fentanyl', 'Heroin'])]

opioid_seizures = southwest_border_data.groupby(['FY', 'Drug Type'])['Sum Qty (lbs)'].sum().reset_index()

opioid_seizures
# Out:
#      FY Drug Type  Sum Qty (lbs)
# 0  2019  Fentanyl    2633.288936
# 1  2019    Heroin    5552.484636
# 2  2020  Fentanyl    9115.477886
# 3  2020    Heroin   10313.920877
# 4  2021  Fentanyl   21172.776053
# 5  2021    Heroin    9938.517200
# 6  2022  Fentanyl   28208.223315
# 7  2022    Heroin    2995.179304
# 8  2023  Fentanyl   26717.833924
# 9  2023    Heroin    1214.168220

# %%
pivot_table = opioid_seizures.pivot(index="FY", columns="Drug Type", values="Sum Qty (lbs)")

plt.figure(figsize=(10, 6))
plot = sns.barplot(data=pivot_table, palette="muted")
plot.set_title("Opioid Seizures at the American Southern Border (FY 2019-2023)")
plot.set_ylabel("Sum Quantity of Drugs Seized (lbs)")
plot.set_xlabel("Fiscal Year")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='FY', y='Sum Qty (lbs)', hue='Drug Type', data=opioid_seizures)
bar_plot.set_title("Opioid Seizures at the American Southern Border (FY 2019-2023)")
bar_plot.set_xlabel("Fiscal Year")
bar_plot.set_ylabel("Sum Quantity of Drugs Seized (lbs)")

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
custom_palette = {"Heroin": "darkgreen", "Fentanyl": "darkred"}

plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='FY', y='Sum Qty (lbs)', hue='Drug Type', data=opioid_seizures, palette=custom_palette)
bar_plot.set_title("Opioid Seizures at the American Southern Border (FY 2019-2023)")
bar_plot.set_xlabel("Fiscal Year")
bar_plot.set_ylabel("Sum Quantity of Drugs Seized (lbs)")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
